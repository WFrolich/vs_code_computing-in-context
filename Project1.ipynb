# %% [markdown]
# # Project 1 - Data Analysis in Python and Pandas
# ## Importing Building Data from NYC Open Data
#  - The data is imported as a csv, downloaded to the local directory from [NYC Open Data Building Energy](https://data.cityofnewyork.us/Environment/NYC-Building-Energy-and-Water-Data-Disclosure-for-/5zyy-y8am/about_data) and renamed *nyc_building_energy.csv*.
#  - Using the DictReader method the data is read and turned into a dictionary. The keys for each row are then printed to see the labels of each column in the file.

# %%
import plotly
import csv
with open('nyc_building_energy.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row.keys())
        break
# Out:
# dict_keys(['Calendar Year', 'Property ID', 'Property Name', 'Parent Property ID', 'Parent Property Name', 'Year Ending', 'NYC Borough, Block and Lot (BBL)', 'NYC Building Identification Number (BIN)', 'Address 1', 'City', 'Postal Code', 'Primary Property Type - Self Selected', 'Primary Property Type - Portfolio Manager-Calculated', 'National Median Reference Property Type', 'List of All Property Use Types (GFA) (ft²)', 'Largest Property Use Type', 'Largest Property Use Type - Gross Floor Area (ft²)', '2nd Largest Property Use Type', '2nd Largest Property Use Type - Gross Floor Area (ft²)', '3rd Largest Property Use Type', '3rd Largest Property Use Type - Gross Floor Area (ft²)', 'Year Built', 'Construction Status', 'Number of Buildings', 'Occupancy', 'Metered Areas (Energy)', 'Metered Areas (Water)', 'ENERGY STAR Score', 'National Median ENERGY STAR Score', 'Target ENERGY STAR Score', 'Reason(s) for No Score', 'ENERGY STAR Certification - Year(s) Certified (Score)', 'Eligible for Certification for Report PED (Y/N)', 'ENERGY STAR Certification - Last Approval Date', 'ENERGY STAR Certification - Application Status', 'Site EUI (kBtu/ft²)', 'Weather Normalized Site EUI (kBtu/ft²)', 'National Median Site EUI (kBtu/ft²)', 'Site Energy Use (kBtu)', 'Weather Normalized Site Energy Use (kBtu)', 'Electricity - Weather Normalized Site Electricity Use (Grid and Onsite Renewables) (kWh)', 'Electricity - Weather Normalized Site Electricity Intensity (Grid and Onsite Renewables) (kWh/ft²)', 'Percent Electricity', 'Natural Gas - Weather Normalized Site Natural Gas Use (therms)', 'Natural Gas - Weather Normalized Site Natural Gas Intensity (therms/ft²)', 'Source EUI (kBtu/ft²)', 'Weather Normalized Source EUI (kBtu/ft²)', 'National Median Source EUI (kBtu/ft²)', 'Source Energy Use (kBtu)', 'Weather Normalized Source Energy Use (kBtu)', 'Fuel Oil #1 Use (kBtu)', 'Fuel Oil #2 Use (kBtu)', 'Fuel Oil #4 Use (kBtu)', 'Fuel Oil #5 & 6 Use (kBtu)', 'Diesel #2 Use (kBtu)', 'Propane Use (kBtu)', 'Kerosene Use (kBtu)', 'District Steam Use (kBtu)', 'District Hot Water Use (kBtu)', 'District Chilled Water Use (kBtu)', 'Natural Gas Use (kBtu)', 'Natural Gas Use (therms)', 'Electricity Use - Grid Purchase (kBtu)', 'Electricity Use - Grid Purchase (kWh)', 'Electricity Use - Grid Purchase and Generated from Onsite Renewable Systems (kWh)', 'Electricity Use - Grid Purchase and Generated from Onsite Renewable Systems (kBtu)', 'Electricity Use – Generated from Onsite Renewable Systems and Used Onsite (kWh)', 'Electricity Use – Generated from Onsite Renewable Systems and Used Onsite (kBtu)', 'Electricity Use – Generated from Onsite Renewable Systems (kWh)', 'Electricity Use – Generated from Onsite Renewable Systems and Exported (kWh)', 'Annual Maximum Demand (kW)', 'Annual Maximum Demand (MM/YYYY)', 'Annual Maximum Demand (Meter Name (Meter ID))', 'Green Power - Onsite (kWh)', 'Green Power - Offsite (kWh)', 'Green Power - Onsite and Offsite (kWh)', 'Total (Location-Based) GHG Emissions (Metric Tons CO2e)', 'Total (Location-Based) GHG Emissions Intensity (kgCO2e/ft²)', 'Direct GHG Emissions (Metric Tons CO2e)', 'Direct GHG Emissions Intensity (kgCO2e/ft²)', 'Indirect (Location-Based) GHG Emissions (Metric Tons CO2e)', 'Indirect (Location-Based) GHG Emissions Intensity (kgCO2e/ft²)', 'Net Emissions (Metric Tons CO2e)', 'National Median Total (Location-Based) GHG Emissions (Metric Tons CO2e)', 'Avoided Emissions - Onsite Green Power (Metric Tons CO2e)', 'Avoided Emissions - Offsite Green Power (Metric Tons CO2e)', 'Avoided Emissions - Onsite and Offsite Green Power (Metric Tons CO2e)', 'Percent of Electricity that is Green Power', 'Percent of RECs Retained', 'Percent of Total Electricity Generated from Onsite Renewable Systems', 'LEED US Project ID', 'Default Values', 'Temporary Values', 'Estimated Values - Energy', 'Estimated Values - Water', 'Alert - Energy Meter has less than 12 full calendar months of data', 'Alert - Energy Meter has gaps', 'Alert - Energy Meter ...

# %% [markdown]
# ## Using Python to Understand the Data:
# ### Making the Data Readable
#  - Again using the DictReader method, the data is added to a list called *data*. The first row of data is printed.

# %%
data = []
with open('nyc_building_energy.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(row)

data[:1]
# Out:
# [{'Calendar Year': '2022',
#   'Property ID': '6414946',
#   'Property Name': '58-01 Grand Avenue',
#   'Parent Property ID': 'Not Applicable: Standalone Property',
#   'Parent Property Name': 'Not Applicable: Standalone Property',
#   'Year Ending': '12/31/2022',
#   'NYC Borough, Block and Lot (BBL)': '4026780001',
#   'NYC Building Identification Number (BIN)': '4059918',
#   'Address 1': '58-01 Grand Avenue',
#   'City': 'Queens',
#   'Postal Code': '11378',
#   'Primary Property Type - Self Selected': 'Non-Refrigerated Warehouse',
#   'Primary Property Type - Portfolio Manager-Calculated': 'Non-Refrigerated Warehouse',
#   'National Median Reference Property Type': 'CBECS - Non-Refrigerated Warehouse',
#   'List of All Property Use Types (GFA) (ft²)': 'Non-Refrigerated Warehouse (51749.0)',
#   'Largest Property Use Type': 'Non-Refrigerated Warehouse',
#   'Largest Property Use Type - Gross Floor Area (ft²)': '51749',
#   '2nd Largest Property Use Type': 'Not Available',
#   '2nd Largest Property Use Type - Gross Floor Area (ft²)': 'Not Available',
#   '3rd Largest Property Use Type': 'Not Available',
#   '3rd Largest Property Use Type - Gross Floor Area (ft²)': 'Not Available',
#   'Year Built': '1930',
#   'Construction Status': 'Existing',
#   'Number of Buildings': '1',
#   'Occupancy': '50',
#   'Metered Areas (Energy)': 'Whole Property',
#   'Metered Areas (Water)': 'Whole Property',
#   'ENERGY STAR Score': '96',
#   'National Median ENERGY STAR Score': '50',
#   'Target ENERGY STAR Score': 'Not Available',
#   'Reason(s) for No Score': 'Not Available',
#   'ENERGY STAR Certification - Year(s) Certified (Score)': 'Not Available',
#   'Eligible for Certification for Report PED (Y/N)': '',
#   'ENERGY STAR Certification - Last Approval Date': 'Not Available',
#   'ENERGY STAR Certification - Application Status': '',
#   'Site EUI (kBtu/ft²)': '10.1',
#   'Weather Normalized Site EUI (kBtu/ft²)': '10.6',
#   'National Median Site EUI (kBtu/ft²)': '43.4',
#   'Site Energy Use (kBtu)': '520173',
#   'Weather Normalized Site Energy Use (kBtu)': '549073.9',
#   'Electricity - Weather Normalized Site Electricity Use (Grid and Onsite Renewables) (kWh)': '20801',
#   'Electricity - Weather Normalized Site Electricity Intensity (Grid and Onsite Renewables) (kWh/ft²)': '0.4',
#   'Percent Electricity': '',
#   'Natural Gas - Weather Normalized Site Natural Gas Use (therms)': '4781',
#   'Natural Gas - Weather Normalized Site Natural Gas Intensity (therms/ft²)': '0.1',
#   'Source EUI (kBtu/ft²)': '13',
#   'Weather Normalized Source EUI (kBtu/ft²)': '13.5',
#   'National Median Source EUI (kBtu/ft²)': '55.9',
#   'Source Energy Use (kBtu)': '670384.4',
#   'Weather Normalized Source Energy Use (kBtu)': '700730.4',
#   'Fuel Oil #1 Use (kBtu)': 'Not Available',
#   'Fuel Oil #2 Use (kBtu)': 'Not Available',
#   'Fuel Oil #4 Use (kBtu)': 'Not Available',
#   'Fuel Oil #5 & 6 Use (kBtu)': 'Not Available',
#   'Diesel #2 Use (kBtu)': 'Not Available',
#   'Propane Use (kBtu)': 'Not Available',
#   'Kerosene Use (kBtu)': 'Not Available',
#   'District Steam Use (kBtu)': 'Not Available',
#   'District Hot Water Use (kBtu)': 'Not Available',
#   'District Chilled Water Use (kBtu)': 'Not Available',
#   'Natural Gas Use (kBtu)': '449200',
#   'Natural Gas Use (therms)': '',
#   'Electricity Use - Grid Purchase (kBtu)': '70973',
#   'Electricity Use - Grid Purchase (kWh)': '20801',
#   'Electricity Use - Grid Purchase and Generated from Onsite Renewable Systems (kWh)': '20801',
#   'Electricity Use - Grid Purchase and Generated from Onsite Renewable Systems (kBtu)': '70973',
#   'Electricity Use – Generated from Onsite Renewable Systems and Used Onsite (kWh)': 'Not Available',
#   'Electricity Use – Generated from Onsite Renewable Systems and Used Onsite (kBtu)': 'Not Available',
#   'Electricity Use – Generated from Onsite Renewable Systems (kWh)': 'Not Available',
#   'Electricity Use – Generated from Onsite Renewable Systems and Exported (kWh)': 'Not Available',
#   'Annual Maximum Demand (kW)': 'Not Available',
#   'Annual Maximum Demand (MM/YYYY)': 'Not Available',
#   'Annual Maximum Demand (Meter Name (Meter ID))': 'Not Available',
#   'Green Power - Onsite (kWh)': 'Not Available',
#   'Green Power - Offsite (kWh)': '0',
#   'Green Power - Onsite and Offsite (kWh)': '0',
#   'Total (Location-Based) GHG Emissions (Metric Tons CO2e)': '29.9',
#   'Total (Location-Based) GHG Emissions Intensity (kgCO2e/ft²)': '0.6',
#   'Direct GHG Emissions (Metric Tons CO2e)': '23.9',
#   'Direct GHG Emissions Intensity (kgCO2e/ft²)': '0.5',
#   'Indirect (Location-Based) GHG Emissions (Metric Tons CO2e)': '6',
#   'Indirect (Location-Based) GHG Emissions Intensity (kgCO2e/ft²)': '0.1',
#   'Net Emissions (Metric Tons CO2e)': '29.9',
#   'National Median Total (Location-Based) GHG Emissions (Metric Tons CO2e)': '129',
#   'Avoided Emissions - Onsite Green Power (Metric Tons CO2e)': 'Not Available',
#   'Avoided Emissions - Offsite Green Power (Metric Tons CO2e)': '0',
#   'Avoided Emissions - Onsite and Offsite Green Power (Metric Tons CO2e)': '0',
#   'Percent of Electricity that is Green Power': '0',
#   'Percent of RECs Retained': 'Not Available',
#   'Percent of Total Electricity Generated from Onsite Renewable Systems': 'Not Available',
#   'LEED US Project ID': 'Not Available',
#   'Default Values': 'false',
#   'Temporary Values': 'false',
#   'Estimated Values - Energy': 'No',
#   'Estimated Values - Water': 'No',
#   'Alert - Energy Meter has less than 12 full calendar months of data': 'Ok',
#   'Alert - Energy Meter has gaps': 'Ok',
#   'Alert - Energy Meter has overlaps': 'Ok',
#   'Alert - Energy - No meters selected for metrics': 'Ok',
#   'Alert - Energy Meter has single entry more than 65 days': 'Ok',
#   'Alert - Property has no uses': 'Ok',
#   'Alert - Water Meter has less than 12 full calendar months of data': 'Ok',
#   'Alert - Data Center Issue (with Estimates, IT Configuration, or IT Meter)': 'Ok',
#   'Alert - Gross Floor Area is 0 ft2': 'Ok',
#   'Estimated Data Flag - Electricity (Grid Purchase)': 'No',
#   'Estimated Data Flag - Natural Gas': 'No',
#   'Estimated Data Flag - District Steam': 'Not Available',
#   'Estimated Data Flag - Municipally Supplied Potable Water: Mixed Indoor/Outdoor Use': 'Not Available',
#   'Estimated Data Flag - Fuel Oil (No. 1)': 'Not Available',
#   'Estimated Data Flag - Fuel Oil (No. 2)': 'Not Available',
#   'Estimated Data Flag - Fuel Oil (No. 4)': 'Not Available',
#   'Estimated Data Flag - Fuel Oil (No. 5 and No. 6)': 'Not Available',
#   'Estimated Data Flag - Diesel': 'Not Available',
#   'Estimated Data Flag - Electricity (Onsite Solar)': 'Not Available',
#   'Data Center - UPS Output Meter (kWh)': 'Not Available',
#   'Data Center - PDU Input Meter (kWh)': 'Not Available',
#   'Data Center - PDU Output Meter (kWh)': 'Not Available',
#   'Data Center - IT Equipment Input Meter (kWh)': 'Not Available',
#   'Data Center - IT Site Energy (kWh)': 'Not Available',
#   'Data Center - IT Source Energy (kBtu)': 'Not Available',
#   'Data Center - PUE': 'Not Available',
#   'Data Center - National Median PUE': 'Not Available',
#   'Data Center - Gross Floor Area (ft²)': 'Not Available',
#   'Data Center - UPS System Redundancy': 'Not Available',
#   'Data Center - IT Energy Configuration': 'Not Available',
#   'Data Center - Energy Estimates Applied': 'Not Available',
#   'Data Center - Cooling Equipment Redundancy': 'Not Available',
#   'Adult Education - Gross Floor Area (ft²)': 'Not Available',
#   'Ambulatory Surgical Center - Gross Floor Area (ft²)': 'Not Available',
#   'Vehicle Dealership - Gross Floor Area (ft²)': 'Not Available',
#   'Bank Branch - Gross Floor Area (ft²)': 'Not Available',
#   'Barracks- Gross Floor Area (ft²)': 'Not Available',
#   'College/University - Gross Floor Area (ft²)': 'Not Available',
#   'Convention Center - Gross Floor Area (ft²)': 'Not Available',
#   'Courthouse - Gross Floor Area (ft²)': 'Not Available',
#   'Distribution Center - Gross Floor Area (ft²)': 'Not Available',
#   'Enclosed Mall - Gross Floor Area (ft²)': 'Not Available',
#   'Energy/Power Station - Gross Floor Area (ft²)': 'Not Available',
#   'Financial Office - Gross Floor Area (ft²)': 'Not Available',
#   'Financial Office - Number of Computers': 'Not Available',
#   'Financial Office - Weekly Operating Hours': 'Not Available',
#   'Financial Office - Number of Workers on Main Shift': 'Not Available',
#   'Fitness Center/Health Club/Gym - Gross Floor Area (ft²)': 'Not Available',
#   'Food Sales - Gross Floor Area (ft²)': 'Not Available',
#   'Food Service - Gross Floor Area (ft²)': 'Not Available',
#   'Hospital (General Medical & Surgical) - Full-Time Equivalent (FTE) Workers': 'Not Available',
#   'Hospital (General Medical & Surgical) - Gross Floor Area (ft²)': 'Not Available',
#   'Hospital (General Medical & Surgical) - Laboratory': 'Not Available',
#   'Hospital (General Medical & Surgical) - Licensed Bed Capacity': 'Not Available',
#   'Hospital (General Medical & Surgical) - Number of MRI Machines': 'Not Available',
#   'Hospital (General Medical & Surgical) - MRI Density (Number per 1,000 sq ft)': 'Not Available',
#   'Hospital (General Medical & Surgical) - Number of Staffed Beds': 'Not Available',
#   'Hospital (General Medical & Surgical) - Staffed Bed Density (Number per 1,000 sq ft)': 'Not Available',
#   'Hospital (General Medical & Surgical) - Full-Time Equivalent (FTE) Worker Density (Number per 1,000 sq ft)': 'Not Available',
#   'Hospital (General Medical & Surgical) - Percent That Can Be Cooled': 'Not Available',
#   'Hospital (General Medical & Surgical) - Percent That Can Be Heated': 'Not Available',
#   'Medical Office - Gross Floor Area (ft²)': 'Not Available',
#   'Medical Office - Number of Computers': 'Not Available',
#   'Medical Office - Number of MRI Machines': 'Not Available',
#   'Medical Office - Number of Workers on Main Shift': 'Not Available',
#   'Medical Office - Percent That Can Be Cooled': 'Not Available',
#   'Medical Office - Percent That Can Be Heated': 'Not Available',
#   'Medical Office - Weekly Operating Hours': 'Not Available',
#   'Outpatient Rehabilitation/Physical Therapy - Gross Floor Area (ft²)': 'Not Available',
#   'Urgent Care/Clinic/Other Outpatient - Gross Floor Area (ft²)': 'Not Available',
#   'Hotel - Gross Floor Area (ft²)': 'Not Available',
#   'Hotel - Gym/fitness  Center Floor Area (ft²)': 'Not Available',
#   'K-12 School - Gross Floor Area (ft²)': 'Not Available',
#   'Pre-school/Daycare - Gross Floor Area (ft²)': 'Not Available',
#   'Laboratory - Gross Floor Area (ft²)': 'Not Available',
#   'Mailing Center/Post Office - Gross Floor Area (ft²)': 'Not Available',
#   'Movie Theater - Gross Floor Area (ft²)': 'Not Available',
#   'Manufacturing/Industrial Plant - Gross Floor Area (ft²)': 'Not Available',
#   'Multifamily Housing - Government Subsidized Housing': 'Not Available',
#   'Institutional Property? (Y/N)': '',
#   'Multifamily Housing - Gross Floor Area (ft²)': 'Not Available',
#   'Multifamily Housing - Number of Bedrooms': 'Not Available',
#   'Multifamily Housing - Number of Bedrooms Density (Number per 1,000 sq ft)': 'Not Available',
#   'Multifamily Housing - Number of Laundry Hookups in All Units': 'Not Available',
#   'Multifamily Housing - Number of Laundry Hookups in Common Area(s)': 'Not Available',
#   'Multifamily Housing - Number of Residential Living Units in a High-Rise Building (10 or more Stories)': 'Not Available',
#   'Multifamily Housing - Percent That Can Be Cooled': 'Not Available',
#   'Multifamily Housing - Percent That Can Be Heated': 'Not Available',
#   'Multifamily Housing - Total Number of Residential Living Units': 'Not Available',
#   'Multifamily Housing - Total Number of Residential Living Units Density (Number per 1,000 sq ft)': 'Not Available',
#   'Multifamily Housing - Number of Residential Living Units in a High-Rise Building Density (Number per 1,000 sq ft)': 'Not Available',
#   'Multifamily Housing - Number of Residential Living Units in a Mid-Rise Building (5-9 Stories)': 'Not Available',
#   'Multifamily Housing - Number of Residential Living Units in a Mid-Rise Building Density (Number per 1,000 sq ft)': 'Not Available',
#   'Multifamily Housing - Resident Population Type': 'Not Available',
#   'Residence Hall/Dormitory - Gross Floor Area (ft²)': 'Not Available',
#   'Refrigerated Warehouse - Gross Floor Area (ft²)': 'Not Available',
#   'Non-Refrigerated Warehouse - Gross Floor Area (ft²)': '51749',
#   'Office - Gross Floor Area (ft²)': 'Not Available',
#   'Office - Number of Computers': 'Not Available',
#   'Office - Number of Workers on Main Shift': 'Not Available',
#   'Office - Percent That Can Be Cooled': 'Not Available',
#   'Office - Percent That Can Be Heated': 'Not Available',
#   'Office - Weekly Operating Hours': 'Not Available',
#   'Office - Worker Density (Number per 1,000 sq ft)': 'Not Available',
#   'Other - Gross Floor Area (ft²)': 'Not Available',
#   'Museum - Gross Floor Area (ft²)': 'Not Available',
#   'Performing Arts - Gross Floor Area (ft²)': 'Not Available',
#   'Parking - Gross Floor Area (ft²)': 'Not Available',
#   'Parking - Open Parking Lot Size (ft²)': 'Not Available',
#   'Parking - Completely Enclosed Parking Garage Size (ft²)': 'Not Available',
#   'Parking - Partially Enclosed Parking Garage Size (ft²)': 'Not Available',
#   'Restaurant - Gross Floor Area (ft²)': 'Not Available',
#   'Restaurant - Weekly Operating Hours': 'Not Available',
#   'Restaurant - Worker Density (Number per 1,000 sq ft)': 'Not Available',
#   'Retail Store - Gross Floor Area (ft²)': 'Not Available',
#   'Retail Store - Number of Walk-in Refrigeration/Freezer Units': 'Not Available',
#   'Retail Store - Number of Open or Closed Refrigeration/Freezer Units': 'Not Available',
#   'Self-Storage Facility - Gross Floor Area (ft²)': 'Not Available',
#   'Senior Living Community - Gross Floor Area (ft²)': 'Not Available',
#   'Senior Living Community - Living Unit Density (Number per 1,000 sq ft)': 'Not Available',
#   'Social/Meeting Hall - Gross Floor Area (ft²)': 'Not Available',
#   'Supermarket/Grocery - Gross Floor Area (ft²)': 'Not Available',
#   'Supermarket/Grocery - Number of Walk-in Refrigeration/Freezer Units': 'Not Available',
#   'Supermarket/Grocery - Number of Open or Closed Refrigeration/Freezer Units': 'Not Available',
#   'Wholesale Club/Supercenter- Gross Floor Area (ft²)': 'Not Available',
#   'Wholesale Club/Supercenter- Exterior Entrance to the Public': 'Not Available',
#   'Wastewater Treatment Plant - Gross Floor Area (ft²)': 'Not Available',
#   'Worship Facility - Gross Floor Area (ft²)': 'Not Available',
#   'Strip Mall - Gross Floor Area (ft²)': 'Not Available',
#   'Property GFA - Self-Reported (ft²)': '51749',
#   'Property GFA - Calculated (Buildings and Parking) (ft²)': '51749',
#   'Property GFA - Calculated (Buildings) (ft²)': '51749',
#   'Property GFA - Calculated (Parking) (ft²)': 'Not Available',
#   'Property Notes': 'Not Available',
#   'Water Use (All Water Sources) (kgal)': '9',
#   'Indoor Water Use (All Water Sources) (kgal)': '9',
#   'Outdoor Water Use (All Water Sources) (kgal)': 'Not Available',
#   'Municipally Supplied Potable Water - Mixed Indoor/Outdoor Use (kgal)': 'Not Available',
#   'Municipally Supplied Potable Water - Total Use (All Meter Types) (kgal)': '9',
#   'Municipally Supplied Potable Water - Indoor Use (kgal)': '9',
#   'Municipally Supplied Potable Water - Outdoor Use (kgal)': 'Not Available',
#   'Third Party Certification': 'Not Available',
#   'Third Party Certification Date Anticipated': 'Not Available',
#   'Third Party Certification Date Achieved': 'Not Available',
#   'Data Quality Checker Run?': '',
#   'Data Quality Checker - Date Run': '',
#   'Last Modified Date - Property': '04/24/2023 12:00:00 AM',
#   'Last Modified Date - Electric Meters': '04/24/2023 12:00:00 AM',
#   'Electric Distribution Utility': '',
#   'Last Modified Date - Gas Meters': '04/07/2023 12:00:00 AM',
#   'Last Modified Date - Non-Electric Non-Gas Energy Meters': '',
#   'Last Modified Date - Water Meters': '03/10/2023 12:00:00 AM',
#   'Last Modified Date - Property Use': '06/10/2021 12:00:00 AM',
#   'Last Modified Date - Property Use Details': '06/10/2021 12:00:00 AM',
#   'Number of Active Energy Meters - Total': '3',
#   'Number of Active Energy Meters - Used to Compute Metrics': '3',
#   'Number of Active Energy Meters - Not Used to Compute Metrics': '0',
#   'Number of Active IT Meters': '0',
#   'Aggregate Meter(s)-Electric – Number of Individual Meters Included': '',
#   'Aggregate Meter(s)-Natural Gas – Number of Individual Meters Included': '',
#   'Aggregate Meter(s)-District Steam – Number of Individual Meters Included': '',
#   'Report Generation Date': '04/25/2023 11:01:44 AM',
#   'Report Submission Date': '04/25/2023 11:02:08 AM',
#   'Borough': 'QUEENS',
#   'Latitude': '40.719667',
#   'Longitude': '-73.911197',
#   'Community Board': '405',
#   'Council District': '30',
#   'Census Tract (2020)': '531',
#   'Neighborhood Tabulation Area (NTA) (2020)': 'QN0501'}]

# %% [markdown]
# - Once the data is in a list, a new list is created to filter the data down to just include the Total Greenhouse Gas Emissions data, converting the text to a float and removing any rows that do not have numeric data.

# %%
ghg_emissions =[]
ghg_emissions = [float(row['Total (Location-Based) GHG Emissions (Metric Tons CO2e)']) for row in data if row['Total (Location-Based) GHG Emissions (Metric Tons CO2e)']!= 'Not Available']

# %% [markdown]
# ### Finding the Mean Greenhouse Gas Emissions Using Basic Python
# - Using the list *ghg_emissions* and the sum function, the total greenhouse gas emissions is calculated.
# - Next, the mean is found by dividing the total amount by the length of the original list, *ghg_emissions*.

# %%
total_ghg = sum(ghg_emissions)
mean_ghg_emissions = total_ghg/len(ghg_emissions)
print('The mean greenhouse gas emissions by buildings in NYC is', mean_ghg_emissions, 'metric tons of CO2e')
# Out:
# The mean greenhouse gas emissions by buildings in NYC is 914.1075328485776 metric tons of CO2e

# %% [markdown]
# ### Finding the Median Greenhouse Gas Emissions Using Basic Python
# - First, the list *ghg_emissions* is sorted using the .sort method.
# - Next, the length of the list is calculated to be able to index the middle of the list.
# - Because the length of the list is even, the median is calculated using the mean of the middle two values of the list.

# %%
ghg_emissions.sort()
length = len(ghg_emissions)
length
# Out:
# 62712

# %%
ghg_emissions[(length//2)]
# Out:
# 292.2

# %%
median = (ghg_emissions[(length//2)] + ghg_emissions[((length//2)-1)])/2
print('The median amount of GHG emissions for buildings in NYC is', median,'metric tons of CO2e')
# Out:
# The median amount of GHG emissions for buildings in NYC is 292.2 metric tons of CO2e

# %% [markdown]
# ### Finding the Mode Greenhouse Gas Emissions Using Basic Python
# - To find the mode, an empty dictionary *counts* is setup and a for loop is used to go through the list *ghg_emissisions* and add each value to the dictionary as a key and then add 1 if the value was already in the dictionary

# %%
counts = {}
for row in ghg_emissions:
    if row in counts:
        counts[row]+=1
    else:
        counts[row]=1
counts
# Out:
# {-43.9: 1,
#  -36.2: 1,
#  0.0: 3133,
#  0.1: 10,
#  0.2: 8,
#  0.3: 11,
#  0.4: 13,
#  0.5: 11,
#  0.6: 18,
#  0.7: 14,
#  0.8: 8,
#  0.9: 8,
#  1.0: 4,
#  1.1: 12,
#  1.2: 5,
#  1.3: 6,
#  1.4: 9,
#  1.5: 5,
#  1.6: 6,
#  1.7: 10,
#  1.8: 4,
#  1.9: 7,
#  2.0: 7,
#  2.1: 2,
#  2.2: 4,
#  2.3: 4,
#  2.4: 9,
#  2.5: 3,
#  2.6: 6,
#  2.7: 7,
#  2.8: 10,
#  2.9: 6,
#  3.0: 7,
#  3.1: 9,
#  3.2: 9,
#  3.3: 9,
#  3.4: 7,
#  3.5: 3,
#  3.6: 5,
#  3.7: 5,
#  3.8: 3,
#  3.9: 7,
#  4.0: 7,
#  4.1: 9,
#  4.2: 8,
#  4.3: 8,
#  4.4: 6,
#  4.5: 3,
#  4.6: 7,
#  4.7: 3,
#  4.8: 3,
#  4.9: 9,
#  5.0: 7,
#  5.1: 9,
#  5.2: 9,
#  5.3: 10,
#  5.4: 8,
#  5.5: 4,
#  5.6: 8,
#  5.7: 4,
#  5.8: 7,
#  5.9: 4,
#  6.0: 5,
#  6.1: 5,
#  6.2: 7,
#  6.3: 4,
#  6.4: 8,
#  6.5: 5,
#  6.6: 7,
#  6.7: 2,
#  6.8: 4,
#  6.9: 5,
#  7.0: 9,
#  7.1: 6,
#  7.2: 4,
#  7.3: 10,
#  7.4: 8,
#  7.5: 7,
#  7.6: 5,
#  7.7: 3,
#  7.8: 2,
#  7.9: 6,
#  8.0: 4,
#  8.1: 8,
#  8.2: 6,
#  8.3: 4,
#  8.4: 6,
#  8.5: 8,
#  8.6: 4,
#  8.7: 3,
#  8.8: 5,
#  8.9: 1,
#  9.0: 5,
#  9.1: 4,
#  9.2: 6,
#  9.3: 3,
#  9.4: 7,
#  9.5: 7,
#  9.6: 8,
#  9.7: 4,
#  9.8: 6,
#  9.9: 7,
#  10.0: 2,
#  10.1: 2,
#  10.2: 9,
#  10.3: 5,
#  10.4: 1,
#  10.5: 3,
#  10.6: 5,
#  10.7: 4,
#  10.8: 5,
#  10.9: 4,
#  11.0: 8,
#  11.1: 5,
#  11.2: 3,
#  11.3: 4,
#  11.4: 8,
#  11.5: 6,
#  11.6: 6,
#  11.7: 5,
#  11.8: 2,
#  11.9: 10,
#  12.0: 5,
#  12.1: 1,
#  12.2: 9,
#  12.3: 8,
#  12.4: 2,
#  12.5: 3,
#  12.6: 6,
#  12.7: 4,
#  12.8: 6,
#  12.9: 2,
#  13.0: 4,
#  13.1: 5,
#  13.2: 7,
#  13.3: 5,
#  13.4: 2,
#  13.5: 2,
#  13.6: 1,
#  13.7: 4,
#  13.8: 2,
#  13.9: 10,
#  14.0: 5,
#  14.1: 1,
#  14.2: 5,
#  14.3: 3,
#  14.4: 3,
#  14.5: 5,
#  14.6: 1,
#  14.7: 6,
#  14.8: 3,
#  14.9: 5,
#  15.0: 1,
#  15.1: 6,
#  15.2: 4,
#  15.3: 2,
#  15.4: 5,
#  15.5: 8,
#  15.6: 1,
#  15.7: 7,
#  15.8: 6,
#  15.9: 1,
#  16.0: 2,
#  16.1: 3,
#  16.2: 4,
#  16.3: 3,
#  16.4: 3,
#  16.5: 8,
#  16.6: 7,
#  16.7: 5,
#  16.8: 4,
#  16.9: 5,
#  17.0: 7,
#  17.1: 7,
#  17.2: 8,
#  17.3: 3,
#  17.4: 4,
#  17.5: 3,
#  17.6: 3,
#  17.7: 4,
#  17.8: 8,
#  17.9: 3,
#  18.0: 4,
#  18.1: 3,
#  18.2: 4,
#  18.3: 1,
#  18.4: 6,
#  18.5: 4,
#  18.6: 2,
#  18.7: 3,
#  18.8: 6,
#  18.9: 6,
#  19.0: 2,
#  19.1: 6,
#  19.2: 5,
#  19.3: 4,
#  19.4: 1,
#  19.5: 7,
#  19.6: 2,
#  19.7: 3,
#  19.8: 2,
#  19.9: 1,
#  20.0: 5,
#  20.1: 5,
#  20.2: 4,
#  20.3: 4,
#  20.4: 3,
#  20.5: 2,
#  20.6: 3,
#  20.7: 5,
#  20.8: 1,
#  20.9: 2,
#  21.0: 5,
#  21.1: 3,
#  21.2: 2,
#  21.3: 3,
#  21.4: 5,
#  21.5: 3,
#  21.6: 4,
#  21.7: 6,
#  21.8: 3,
#  21.9: 6,
#  22.0: 3,
#  22.1: 3,
#  22.2: 6,
#  22.3: 4,
#  22.4: 2,
#  22.5: 6,
#  22.6: 2,
#  22.7: 1,
#  22.8: 6,
#  22.9: 1,
#  23.0: 3,
#  23.1: 7,
#  23.2: 4,
#  23.3: 2,
#  23.4: 4,
#  23.5: 4,
#  23.6: 2,
#  23.7: 4,
#  23.8: 6,
#  23.9: 5,
#  24.0: 4,
#  24.1: 5,
#  24.2: 2,
#  24.3: 1,
#  24.4: 6,
#  24.5: 2,
#  24.6: 3,
#  24.7: 5,
#  24.8: 7,
#  24.9: 4,
#  25.0: 4,
#  25.1: 5,
#  25.2: 5,
#  25.3: 4,
#  25.4: 4,
#  25.5: 4,
#  25.6: 3,
#  25.7: 5,
#  25.8: 7,
#  25.9: 3,
#  26.0: 5,
#  26.1: 2,
#  26.2: 2,
#  26.4: 5,
#  26.5: 5,
#  26.6: 6,
#  26.7: 1,
#  26.8: 6,
#  26.9: 2,
#  27.0: 2,
#  27.1: 8,
#  27.2: 4,
#  27.3: 5,
#  27.4: 3,
#  27.5: 2,
#  27.6: 8,
#  27.7: 2,
#  27.8: 4,
#  27.9: 3,
#  28.1: 6,
#  28.2: 5,
#  28.3: 6,
#  28.4: 2,
#  28.5: 7,
#  28.6: 2,
#  28.7: 6,
#  28.8: 5,
#  28.9: 8,
#  29.0: 2,
#  29.1: 5,
#  29.2: 6,
#  29.3: 4,
#  29.4: 8,
#  29.5: 5,
#  29.6: 8,
#  29.7: 5,
#  29.8: 7,
#  29.9: 13,
#  30.0: 4,
#  30.1: 3,
#  30.2: 3,
#  30.3: 5,
#  30.4: 7,
#  30.5: 5,
#  30.6: 2,
#  30.7: 8,
#  30.8: 8,
#  31.0: 5,
#  31.1: 3,
#  31.2: 4,
#  31.3: 9,
#  31.4: 6,
#  31.5: 2,
#  31.6: 4,
#  31.7: 5,
#  31.8: 6,
#  31.9: 3,
#  32.0: 6,
#  32.1: 6,
#  32.2: 1,
#  32.3: 2,
#  32.4: 3,
#  32.5: 7,
#  32.6: 7,
#  32.7: 5,
#  32.8: 6,
#  32.9: 8,
#  33.0: 3,
#  33.1: 4,
#  33.2: 5,
#  33.4: 6,
#  33.5: 3,
#  33.6: 10,
#  33.7: 5,
#  33.8: 7,
#  33.9: 4,
#  34.0: 5,
#  34.1: 6,
#  34.2: 6,
#  34.3: 7,
#  34.4: 5,
#  34.5: 11,
#  34.6: 3,
#  34.7: 5,
#  34.8: 4,
#  34.9: 4,
#  35.0: 7,
#  35.1: 2,
#  35.2: 6,
#  35.3: 6,
#  35.4: 3,
#  35.5: 7,
#  35.6: 2,
#  35.7: 6,
#  35.8: 3,
#  35.9: 7,
#  36.0: 7,
#  36.1: 4,
#  36.2: 6,
#  36.3: 3,
#  36.4: 9,
#  36.5: 3,
#  36.6: 8,
#  36.7: 5,
#  36.8: 11,
#  36.9: 8,
#  37.0: 8,
#  37.1: 5,
#  37.2: 12,
#  37.3: 4,
#  37.4: 2,
#  37.5: 7,
#  37.6: 1,
#  37.7: 3,
#  37.8: 7,
#  37.9: 3,
#  38.0: 4,
#  38.1: 2,
#  38.2: 7,
#  38.3: 10,
#  38.4: 6,
#  38.5: 7,
#  38.6: 7,
#  38.7: 8,
#  38.8: 1,
#  38.9: 9,
#  39.0: 7,
#  39.1: 6,
#  39.2: 5,
#  39.3: 5,
#  39.4: 7,
#  39.5: 5,
#  39.6: 6,
#  39.7: 2,
#  39.8: 9,
#  39.9: 8,
#  40.0: 12,
#  40.1: 9,
#  40.2: 9,
#  40.3: 3,
#  40.4: 7,
#  40.5: 9,
#  40.6: 5,
#  40.7: 6,
#  40.8: 4,
#  40.9: 6,
#  41.0: 7,
#  41.1: 6,
#  41.2: 3,
#  41.3: 5,
#  41.4: 6,
#  41.5: 8,
#  41.6: 8,
#  41.7: 8,
#  41.8: 9,
#  41.9: 6,
#  42.0: 6,
#  42.1: 3,
#  42.2: 4,
#  42.3: 5,
#  42.4: 3,
#  42.5: 9,
#  42.6: 6,
#  42.7: 5,
#  42.8: 10,
#  42.9: 5,
#  43.0: 2,
#  43.1: 2,
#  43.2: 4,
#  43.3: 9,
#  43.4: 6,
#  43.5: 7,
#  43.6: 4,
#  43.7: 3,
#  43.8: 5,
#  43.9: 6,
#  44.0: 5,
#  44.1: 6,
#  44.2: 5,
#  44.3: 7,
#  44.4: 4,
#  44.5: 5,
#  44.6: 2,
#  44.7: 6,
#  44.8: 6,
#  44.9: 3,
#  45.0: 7,
#  45.1: 6,
#  45.2: 5,
#  45.3: 8,
#  45.4: 6,
#  45.5: 3,
#  45.6: 7,
#  45.7: 9,
#  45.8: 3,
#  45.9: 8,
#  46.0: 5,
#  46.1: 10,
#  46.2: 5,
#  46.3: 6,
#  46.4: 6,
#  46.5: 8,
#  46.6: 6,
#  46.7: 9,
#  46.8: 7,
#  46.9: 2,
#  47.0: 11,
#  47.1: 5,
#  47.2: 6,
#  47.3: 6,
#  47.4: 7,
#  47.5: 8,
#  47.6: 5,
#  47.7: 6,
#  47.8: 13,
#  47.9: 6,
#  48.0: 6,
#  48.1: 8,
#  48.2: 8,
#  48.3: 5,
#  48.4: 9,
#  48.5: 4,
#  48.6: 5,
#  48.7: 8,
#  48.8: 5,
#  48.9: 7,
#  49.0: 5,
#  49.1: 5,
#  49.2: 7,
#  49.3: 7,
#  49.4: 2,
#  49.5: 2,
#  49.6: 6,
#  49.7: 8,
#  49.8: 11,
#  49.9: 6,
#  50.0: 5,
#  50.1: 5,
#  50.2: 5,
#  50.3: 3,
#  50.4: 10,
#  50.5: 2,
#  50.6: 6,
#  50.7: 10,
#  50.8: 6,
#  50.9: 11,
#  51.0: 9,
#  51.1: 9,
#  51.2: 4,
#  51.3: 5,
#  51.4: 9,
#  51.5: 6,
#  51.6: 7,
#  51.7: 8,
#  51.8: 6,
#  51.9: 7,
#  52.0: 3,
#  52.1: 1,
#  52.2: 9,
#  52.3: 7,
#  52.4: 5,
#  52.5: 4,
#  52.6: 5,
#  52.7: 7,
#  52.8: 8,
#  52.9: 4,
#  53.0: 9,
#  53.1: 8,
#  53.2: 6,
#  53.3: 9,
#  53.4: 7,
#  53.5: 3,
#  53.6: 8,
#  53.7: 11,
#  53.8: 6,
#  53.9: 4,
#  54.0: 7,
#  54.1: 5,
#  54.2: 4,
#  54.3: 12,
#  54.4: 2,
#  54.5: 6,
#  54.6: 5,
#  54.7: 7,
#  54.8: 5,
#  54.9: 7,
#  55.0: 3,
#  55.1: 9,
#  55.2: 5,
#  55.3: 6,
#  55.4: 5,
#  55.5: 10,
#  55.6: 9,
#  55.7: 5,
#  55.8: 7,
#  55.9: 6,
#  56.0: 3,
#  56.1: 9,
#  56.2: 4,
#  56.3: 5,
#  56.4: 6,
#  56.5: 3,
#  56.6: 3,
#  56.7: 7,
#  56.8: 9,
#  56.9: 5,
#  57.0: 8,
#  57.1: 7,
#  57.2: 4,
#  57.3: 7,
#  57.4: 11,
#  57.5: 2,
#  57.6: 10,
#  57.7: 7,
#  57.8: 5,
#  57.9: 6,
#  58.0: 3,
#  58.1: 4,
#  58.2: 7,
#  58.3: 7,
#  58.4: 9,
#  58.5: 4,
#  58.6: 3,
#  58.7: 8,
#  58.8: 4,
#  58.9: 9,
#  59.0: 6,
#  59.1: 11,
#  59.2: 14,
#  59.3: 13,
#  59.4: 12,
#  59.5: 5,
#  59.6: 6,
#  59.7: 8,
#  59.8: 8,
#  59.9: 6,
#  60.0: 10,
#  60.1: 7,
#  60.2: 4,
#  60.3: 9,
#  60.4: 7,
#  60.5: 5,
#  60.6: 7,
#  60.7: 10,
#  60.8: 3,
#  60.9: 3,
#  61.0: 8,
#  61.1: 5,
#  61.2: 8,
#  61.3: 7,
#  61.4: 6,
#  61.5: 3,
#  61.6: 11,
#  61.7: 9,
#  61.8: 2,
#  61.9: 6,
#  62.0: 14,
#  62.1: 3,
#  62.2: 4,
#  62.3: 10,
#  62.4: 5,
#  62.5: 8,
#  62.6: 4,
#  62.7: 8,
#  62.8: 5,
#  62.9: 7,
#  63.0: 4,
#  63.1: 1,
#  63.2: 7,
#  63.3: 10,
#  63.4: 11,
#  63.5: 7,
#  63.6: 6,
#  63.7: 6,
#  63.8: 7,
#  63.9: 8,
#  64.0: 3,
#  64.1: 8,
#  64.2: 16,
#  64.3: 17,
#  64.4: 9,
#  64.5: 4,
#  64.6: 8,
#  64.7: 8,
#  64.8: 12,
#  64.9: 13,
#  65.0: 8,
#  65.1: 12,
#  65.2: 11,
#  65.3: 14,
#  65.4: 5,
#  65.5: 4,
#  65.6: 6,
#  65.7: 9,
#  65.8: 5,
#  65.9: 6,
#  66.0: 5,
#  66.1: 4,
#  66.2: 3,
#  66.3: 6,
#  66.4: 6,
#  66.5: 4,
#  66.6: 7,
#  66.7: 8,
#  66.8: 3,
#  66.9: 8,
#  67.0: 6,
#  67.1: 6,
#  67.2: 4,
#  67.3: 12,
#  67.4: 7,
#  67.5: 8,
#  67.6: 7,
#  67.7: 5,
#  67.8: 8,
#  67.9: 9,
#  68.0: 3,
#  68.1: 8,
#  68.2: 7,
#  68.3: 7,
#  68.4: 9,
#  68.5: 8,
#  68.6: 9,
#  68.7: 3,
#  68.8: 10,
#  68.9: 9,
#  69.0: 6,
#  69.1: 5,
#  69.2: 8,
#  69.3: 8,
#  69.4: 9,
#  69.5: 5,
#  69.6: 6,
#  69.7: 11,
#  69.8: 6,
#  69.9: 9,
#  70.0: 8,
#  70.1: 14,
#  70.2: 6,
#  70.3: 5,
#  70.4: 11,
#  70.5: 9,
#  70.6: 9,
#  70.7: 2,
#  70.8: 10,
#  70.9: 5,
#  71.0: 5,
#  71.1: 4,
#  71.2: 11,
#  71.3: 7,
#  71.4: 12,
#  71.5: 9,
#  71.6: 9,
#  71.7: 13,
#  71.8: 11,
#  71.9: 6,
#  72.0: 12,
#  72.1: 2,
#  72.2: 7,
#  72.3: 6,
#  72.4: 6,
#  72.5: 6,
#  72.6: 7,
#  72.7: 7,
#  72.8: 7,
#  72.9: 4,
#  73.0: 4,
#  73.1: 6,
#  73.2: 5,
#  73.3: 7,
#  73.4: 6,
#  73.5: 1,
#  73.6: 9,
#  73.7: 4,
#  73.8: 7,
#  73.9: 6,
#  74.0: 4,
#  74.1: 5,
#  74.2: 11,
#  74.3: 3,
#  74.4: 12,
#  74.5: 5,
#  74.6: 8,
#  74.7: 10,
#  74.8: 5,
#  74.9: 10,
#  75.0: 12,
#  75.1: 12,
#  75.2: 7,
#  75.3: 12,
#  75.4: 12,
#  75.5: 6,
#  75.6: 7,
#  75.7: 11,
#  75.8: 7,
#  75.9: 5,
#  76.0: 5,
#  76.1: 9,
#  76.2: 8,
#  76.3: 10,
#  76.4: 5,
#  76.5: 8,
#  76.6: 11,
#  76.7: 1,
#  76.8: 6,
#  76.9: 14,
#  77.0: 12,
#  77.1: 7,
#  77.2: 2,
#  77.3: 11,
#  77.4: 8,
#  77.5: 6,
#  77.6: 6,
#  77.7: 6,
#  77.8: 10,
#  77.9: 5,
#  78.0: 14,
#  78.1: 1,
#  78.2: 5,
#  78.3: 7,
#  78.4: 4,
#  78.5: 3,
#  78.6: 8,
#  78.7: 10,
#  78.8: 7,
#  78.9: 8,
#  79.0: 7,
#  79.1: 12,
#  79.2: 8,
#  79.3: 10,
#  79.4: 4,
#  79.5: 6,
#  79.6: 8,
#  79.7: 5,
#  79.8: 6,
#  79.9: 8,
#  80.0: 7,
#  80.1: 4,
#  80.2: 5,
#  80.3: 11,
#  80.4: 10,
#  80.5: 15,
#  80.6: 2,
#  80.7: 13,
#  80.8: 8,
#  80.9: 6,
#  81.0: 8,
#  81.1: 4,
#  81.2: 11,
#  81.3: 7,
#  81.4: 7,
#  81.5: 7,
#  81.6: 11,
#  81.7: 3,
#  81.8: 8,
#  81.9: 10,
#  82.0: 7,
#  82.1: 4,
#  82.2: 7,
#  82.3: 3,
#  82.4: 4,
#  82.5: 7,
#  82.6: 9,
#  82.7: 9,
#  82.8: 8,
#  82.9: 7,
#  83.0: 10,
#  83.1: 8,
#  83.2: 10,
#  83.3: 12,
#  83.4: 10,
#  83.5: 10,
#  83.6: 7,
#  83.7: 9,
#  83.8: 9,
#  83.9: 11,
#  84.0: 8,
#  84.1: 11,
#  84.2: 3,
#  84.3: 12,
#  84.4: 11,
#  84.5: 12,
#  84.6: 8,
#  84.7: 9,
#  84.8: 9,
#  84.9: 9,
#  85.0: 4,
#  85.1: 10,
#  85.2: 6,
#  85.3: 6,
#  85.4: 9,
#  85.5: 14,
#  85.6: 6,
#  85.7: 7,
#  85.8: 7,
#  85.9: 14,
#  86.0: 15,
#  86.1: 4,
#  86.2: 4,
#  86.3: 6,
#  86.4: 3,
#  86.5: 9,
#  86.6: 8,
#  86.7: 7,
#  86.8: 8,
#  86.9: 5,
#  87.0: 9,
#  87.1: 5,
#  87.2: 13,
#  87.3: 10,
#  87.4: 7,
#  87.5: 11,
#  87.6: 12,
#  87.7: 9,
#  87.8: 8,
#  87.9: 8,
#  88.0: 11,
#  88.1: 12,
#  88.2: 6,
#  88.3: 10,
#  88.4: 4,
#  88.5: 6,
#  88.6: 6,
#  88.7: 6,
#  88.8: 6,
#  88.9: 7,
#  89.0: 8,
#  89.1: 7,
#  89.2: 10,
#  89.3: 11,
#  89.4: 12,
#  89.5: 8,
#  89.6: 13,
#  89.7: 13,
#  89.8: 9,
#  89.9: 4,
#  90.0: 6,
#  90.1: 3,
#  90.2: 14,
#  90.3: 5,
#  90.4: 9,
#  90.5: 11,
#  90.6: 10,
#  90.7: 12,
#  90.8: 8,
#  90.9: 10,
#  91.0: 13,
#  91.1: 10,
#  91.2: 6,
#  91.3: 10,
#  91.4: 2,
#  91.5: 6,
#  91.6: 7,
#  91.7: 7,
#  91.8: 10,
#  91.9: 8,
#  92.0: 6,
#  92.1: 13,
#  92.2: 7,
#  92.3: 7,
#  92.4: 6,
#  92.5: 9,
#  92.6: 4,
#  92.7: 5,
#  92.8: 8,
#  92.9: 12,
#  93.0: 7,
#  93.1: 7,
#  93.2: 9,
#  93.3: 6,
#  93.4: 7,
#  93.5: 9,
#  93.6: 10,
#  93.7: 5,
#  93.8: 8,
#  93.9: 8,
#  94.0: 6,
#  94.1: 11,
#  94.2: 8,
#  94.3: 5,
#  94.4: 5,
#  94.5: 12,
#  94.6: 8,
#  94.7: 8,
#  94.8: 6,
#  94.9: 5,
#  95.0: 11,
#  95.1: 9,
#  95.2: 12,
#  95.3: 3,
#  95.4: 8,
#  95.5: 8,
#  95.6: 10,
#  95.7: 13,
#  95.8: 7,
#  95.9: 7,
#  96.0: 9,
#  96.1: 9,
#  96.2: 8,
#  96.3: 4,
#  96.4: 8,
#  96.5: 10,
#  96.6: 9,
#  96.7: 6,
#  96.8: 7,
#  96.9: 6,
#  97.0: 13,
#  97.1: 14,
#  97.2: 6,
#  97.3: 8,
#  97.4: 10,
#  97.5: 12,
#  97.6: 10,
#  97.7: 7,
#  97.8: 11,
#  97.9: 12,
#  98.0: 4,
#  98.1: 12,
#  98.2: 8,
#  98.3: 11,
#  98.4: 12,
#  98.5: 13,
#  98.6: 12,
#  98.7: 11,
#  98.8: 10,
#  98.9: 11,
#  99.0: 10,
#  99.1: 7,
#  99.2: 12,
#  99.3: 5,
#  99.4: 6,
#  99.5: 2,
#  99.6: 11,
#  99.7: 8,
#  99.8: 7,
#  99.9: 8,
#  100.0: 7,
#  100.1: 6,
#  ...}

# %%
mode = counts[0.0]
print(f'The mode amount of GHG emissions is 0.0 with {mode} entries')
# Out:
# The mode amount of GHG emissions is 0.0 with 3133 entries

# %% [markdown]
# ## Using Pandas:
# ### Turn the Data into a Dataframe
# - Using the pandas package, the data is read into a dataframe using the .read_csv method.

# %%
import pandas as pd

# %%
building_energy_df = pd.read_csv('nyc_building_energy.csv')
# Out:
# /var/folders/7b/lhrpdd1j6pd65g1hqvwlmfph0000gn/T/ipykernel_40295/3322834044.py:1: DtypeWarning: Columns (10,16,32,34,42,54,61,76,77,78,79,80,81,82,91,174,239,240,243) have mixed types. Specify dtype option on import or set low_memory=False.
#   building_energy_df = pd.read_csv('nyc_building_energy.csv')

# %% [markdown]
# ### Exploring and Updating the Data Type
# - Filtering for the column of interest, the .info method is used to see what kind of data is in the relevant column.

# %%
building_energy_df['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 64169 entries, 0 to 64168
# Series name: Total (Location-Based) GHG Emissions (Metric Tons CO2e)
# Non-Null Count  Dtype
# --------------  -----
# 64169 non-null  object
# dtypes: object(1)
# memory usage: 501.4+ KB

# %% [markdown]
# - The column is converted from an object to a float using the .to_numeric method
# - The .info method is then used to check that the change in data types worked as expected

# %%
building_energy_df['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'] = pd.to_numeric(building_energy_df['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'], errors ='coerce')

# %%
building_energy_df['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 64169 entries, 0 to 64168
# Series name: Total (Location-Based) GHG Emissions (Metric Tons CO2e)
# Non-Null Count  Dtype
# --------------  -----
# 62712 non-null  float64
# dtypes: float64(1)
# memory usage: 501.4 KB

# %% [markdown]
# ### Understanding the Data
# - Using the .groupby method, we can start to get a better understand the frequency of entries,

# %%
with pd.option_context("display.max_rows", 1000):
    display(building_energy_df.groupby("Total (Location-Based) GHG Emissions (Metric Tons CO2e)").size())
# Out:
# Total (Location-Based) GHG Emissions (Metric Tons CO2e)
# -43.9            1
# -36.2            1
#  0.0          3133
#  0.1            10
#  0.2             8
#               ...
#  846700.1        1
#  846700.4        1
#  2206862.8       1
#  3134531.6       1
#  3139711.6       1
# Length: 15661, dtype: int64

# %% [markdown]
# - To make sure the series only contains the numeric data, a new slice is created to exclude the rows with "Not Available"

# %%
valid_totals = building_energy_df[building_energy_df['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'] != 'Not Available']
valid_totals['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 64169 entries, 0 to 64168
# Series name: Total (Location-Based) GHG Emissions (Metric Tons CO2e)
# Non-Null Count  Dtype
# --------------  -----
# 62712 non-null  float64
# dtypes: float64(1)
# memory usage: 501.4 KB

# %% [markdown]
# - Before using the median, mean, and mode methods, a new slice is created and sorted to check the possible values of the methods

# %%
counts = valid_totals.groupby("Total (Location-Based) GHG Emissions (Metric Tons CO2e)").size().sort_values(ascending=False).reset_index(name="count")

# %%
counts
# Out:
#        Total (Location-Based) GHG Emissions (Metric Tons CO2e)  count
# 0                                                    0.0         3133
# 1                                                  179.6           27
# 2                                                  218.7           25
# 3                                                  182.7           24
# 4                                                  194.0           23
# ...                                                  ...          ...
# 15656                                             1344.9            1
# 15657                                             1344.5            1
# 15658                                             1344.2            1
# 15659                                             1343.5            1
# 15660                                          3139711.6            1
#
# [15661 rows x 2 columns]

# %% [markdown]
# - Using the .mean method, we find the same mean as the non-pandas process
# - The .median and .mode methods are then used and the same results are found

# %%
pd_mean = valid_totals['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'].mean()
print('The mean of the data is', pd_mean, 'metric tons of CO2e')
# Out:
# The mean of the data is 914.1075328485776 metric tons of CO2e

# %%
pd_median = valid_totals['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'].median()
print('The median of the data is', pd_median,'metric tons of CO2e')
# Out:
# The median of the data is 292.2 metric tons of CO2e

# %%
pd_mode = valid_totals['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'].mode()
print('The mode of the data is', pd_mode, 'metric tons of CO2e')
# Out:
# The mode of the data is 0    0.0
# Name: Total (Location-Based) GHG Emissions (Metric Tons CO2e), dtype: float64 metric tons of CO2e

# %% [markdown]
# The above results match the results from the grouped and sorted dataframe as well as the results from the prior section.

# %% [markdown]
# ## Creating a Simple Visualization
# - First the data is simplified using the groupby method to create a smaller table that can then be visualized. Here, the data is grouped by year.

# %%
yearly_emissions = valid_totals.groupby('Calendar Year')['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'].sum().reset_index()
yearly_emissions
# Out:
#    Calendar Year  Total (Location-Based) GHG Emissions (Metric Tons CO2e)
# 0           2022                                         24574861.9
# 1           2023                                         32750649.7

# %% [markdown]
# - Next, the .info method is used to better understand the type of data within each column.

# %%
yearly_emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Calendar Year                                            2 non-null      int64
#  1   Total (Location-Based) GHG Emissions (Metric Tons CO2e)  2 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 164.0 bytes

# %% [markdown]
# - Lastly, a for loop is used to convert the year into a string and the GHG emissions into an integer. The ghg emissions are then divided by 1 million and then multiplied by the * icon. The result is a simple visual that shows a * for every million metric tons of CO2 of greenhouse gas emissions in each year.

# %%
print('NYC Total Building Greenhouse Gas Emissions (Millions of Metric Tons of CO2e):')
for index, row in yearly_emissions.iterrows():
    # print (row)
    year = str(int(row['Calendar Year']))
    co2 = (row['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'])
    partspermill = int(co2/1000000)
    print(str(int(row['Calendar Year']))), print(partspermill*'*')
# Out:
# NYC Total Building Greenhouse Gas Emissions (Millions of Metric Tons of CO2e):
# 2022
# ************************
# 2023
# ********************************

# %%
# def year_list():
#     year = []
#     for index, row in yearly_emissions.iterrows():
#         # print (row)
#         str_year = [str(int(row['Calendar Year']))]
#         year.append(str_year)
        
#     return year

# def ppm_list():
#     ppm_list = []
#     for index, row in yearly_emissions.iterrows():
#         co2 = (row['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'])
#         ppm = int(co2/1000000)
#         ppm_visual = [ppm*'*']
#         ppm_list.append(ppm_visual)
#     return ppm_list
# ppm_list()
# year_list()
# data = {'Year': year_list,
#         'Parts Per Million': ppm_list}
# data_visual = pd.DataFrame(data)
# data_visual

# %%
# city_emissions = valid_totals.groupby('City')['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'].sum().reset_index()
# city_emissions

# %%
# property_type_emissions = valid_totals.groupby('City')['Total (Location-Based) GHG Emissions (Metric Tons CO2e)'].sum().reset_index()
# property_type_emissions
